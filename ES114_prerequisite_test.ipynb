# %%
#1.List Operations and Basic Statistics:
import math
nums=[]
term=1

#creating list of the first 20 natural numbers
while term<=20:
    nums.append(term)
    term+=1

#computing sum of all even numbers in the list and computing product of all odd numbers in the list
summation=0
product=1
for i in nums:
    if i%2==0:
        summation+=i
    else:
        product*=i


#computing mean,median and standard deviation of the list
def mean_of_list(l):
    sum_of_terms=0
    for i in l:
        sum_of_terms+=i
    mean=(sum_of_terms)/len(l)
    return mean

def median_of_list(l):
    l.sort()
    if len(l)%2!=0:
        target=(len(l)+1)/2
        return l[target]
    else:
        value=(l[int(len(l)/2-1)]+l[int(len(l)/2)])/2 #taking average of 11th and 12th term instead of 10th and 11th because list indexing starts from 0
        return value
def standard_deviation_of_list(l):
    mean=mean_of_list(l)
    sum_of_all_difference_squares=0
    for i in l:
        sum_of_all_difference_squares+=(mean-i)**2
    variance=sum_of_all_difference_squares/len(l)
    return math.sqrt(variance)

#displaying all the values
print("sum of all even numbers:",summation)
print("product of all odd numbers:",product)
print("mean:",mean_of_list(nums))
print("median:",median_of_list(nums))
print("standard deviation:",standard_deviation_of_list(nums))
# Out:
# sum of all even numbers: 110
# product of all odd numbers: 654729075
# mean: 10.5
# median: 10.5
# standard deviation: 5.766281297335398

# %% [markdown]
# 2.Mutable vs. Immutable Data Types:
# Mutable Data Types: These are data types that can have their value changed after defining. Example of Mutable data types are lists and dictionaries.
# Immutable Data types: These are data types whose value cannot be changed once defined. Example of Immutable data types are strings and tuples.

# %%
#3.Fibonacci Sequence:
import matplotlib.pyplot as plt
n=int(input())

#defining two lists,one which stores the value of x and one which stores f(x), f(x) here is the fibonacci value at x.
x_val=[0,1]
fibo_val=[0,1]

#calculating and storing values of f(x) at each value of x up till n.
for i in range(2,n):
    x_val.append(i)
    term=fibo_val[i-1]+fibo_val[i-2]
    fibo_val.append(term)

#plotting x values against values of f(x)
plt.title("Line Graph")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x_val,fibo_val)
plt.show()
# Out:
#  11

# %%
#4.List Manipulation:
l= [3, 5, 7, 9, 11, 13]

#Inserting 6 at 3rd index
l.insert(3,6)

#Removing 7 from the list
l.remove(7)

#Reversing the list
l=l[::-1]

#Calculating Mean and Median of modified list
def mean_of_list(l):
    sum_of_terms=0
    for i in l:
        sum_of_terms+=i
    mean=(sum_of_terms)/len(l)
    return mean

def median_of_list(l):
    l.sort()
    if len(l)%2!=0:
        target=(len(l)+1)/2
        return l[target]
    else:
        value=(l[int(len(l)/2-1)]+l[int(len(l)/2)])/2 
        return value

#Displaying values
print("new list:",l)
print("mean:",mean_of_list(l))
print("median:",median_of_list(l))
# Out:
# new list: [13, 11, 9, 6, 5, 3]
# mean: 7.833333333333333
# median: 7.5

# %%
#5.User Input and Basic Statistics:
nums=list(map(int,input().split(","))) #taking input of comma-separated integers and storing them in a list

#Calculating mean of the numbers
def mean_of_list(l):
    sum_of_terms=0
    for i in l:
        sum_of_terms+=i
    mean=(sum_of_terms)/len(l)
    return mean
print(mean_of_list(nums))

#Printing smallest and largest numbers
nums.sort()
smallest=nums[0] #in a sorted list the first number will be the smallest(index= 0)
largest=nums[-1] #in a sorted list the last number will be the largest(index= -1 or len(l)-1)
print("smallest number:",smallest)
print("largest number:",largest)

#Plotting histogram of the numbers
import matplotlib.pyplot as plt
plt.title("Histogram")
plt.xlabel("Number")
plt.ylabel("Frequency")
plt.hist(nums)
plt.show()
# Out:
#  10,10,10,20,30,30,40,40,70,70,70,70
# 39.166666666666664
# smallest number: 10
# largest number: 70

# %%
#6.Palindrome Check:
s=input() #taking input
s=s.lower() #converting full string to lowercase because question asks us to ignore case
s_stripped=''
for i in s:
    if i!=" ":
        s_stripped+=i #creating a new string consisting of s without any spaces, cause question asks us to ignore spaces
if s_stripped==s_stripped[::-1]:
    print(True)
else:
    print(False)
# Out:
#  A man a plan a canal Panama
# True

# %%
#7.Dictionary Operations:
s=input() #taking the dictionary input as a string
s=s[1:-1] #removing braces {}
data=s.split(",")
student_data={}
#converting string given dictionary into actual dictionary
for i in data:
    term=i.split(":")
    student_data[term[0]]=int(term[1])

#computing average marks
marks=[]
def mean_of_list(l):
    sum_of_terms=0
    for i in l:
        sum_of_terms+=i
    mean=(sum_of_terms)/len(l)
    return mean
for i in student_data:
    marks.append(student_data[i])
average_mark= mean_of_list(marks)
print("average mark:",average_mark)

#printing names of students scoring above average marks
print("Name of students scoring above average marks")
for i in student_data:
    if student_data[i]>average_mark:
        print(i)

#displaying student_data as a bar chart
import matplotlib.pyplot as plt
names=[]
marks=[]
for i in student_data:
    names.append(i)
    marks.append(student_data[i])
plt.title("Bar Chart
plt.bar(names,marks)
plt.show()
# Out:
#  {Prajwal:90,Arun:95,Roopa:95,Anagha:35}
# average mark: 78.75
# Name of students scoring above average marks
# Prajwal
# Arun
# Roopa

# %%
#8.Tuple List Creation:
nums=[]
#creating the list of tuples
for i in range(1,11):
    term=(i,i**2)
    nums.append(term)
    
#plotting a scatter plot
import matplotlib.pyplot as plt
numbers=[]
squares=[]
for i in nums:
    numbers.append(i[0])
    squares.append(i[1])
plt.title("Scatter Chart")
plt.xlabel("X")
plt.ylabel("X^2")
plt.scatter(numbers,squares)
plt.show()

# %%
#9.Merging Dictionaries:
dict1 = {'a': 10, 'b': 20}
dict2 = {'b': 5, 'c': 15}
result={} #stores final dictionary with summed values

#merging both
for i in dict1:
    if i not in result:
        result[i]=dict1[i]
    else:
        result[i]+=dict1[i]
for i in dict2:
    if i not in result:
        result[i]=dict2[i]
    else:
        result[i]+=dict2[i]

#displaying final dictionary with summed values
print(result)
# Out:
# {'a': 10, 'b': 25, 'c': 15}

# %%
#10.Character Frequency:
s=input() #taking input
s=s.lower() #converting full string to lowercase

#counting frequency of each character
char_count={}
for i in s:
    if i not in char_count:
        char_count[i]=1
    else:
        char_count[i]+=1
print(char_count) #displaying frequency of each character

#Displaying character frequency as a bar plot
import matplotlib.pyplot as plt
chars=[]
freq=[]
for i in char_count:
    chars.append(i)
    freq.append(char_count[i])
plt.title("Frequency Bar Chart")
plt.xlabel("Character")
plt.ylabel("Frequency")
plt.bar(chars,freq)
plt.show()
# Out:
#  Hi guys my name is Prajwal Patil and I am part of the PSDV course for the second semester
# {'h': 3, 'i': 4, ' ': 19, 'g': 1, 'u': 2, 'y': 2, 's': 7, 'm': 4, 'n': 3, 'a': 7, 'e': 8, 'p': 4, 'r': 5, 'j': 1, 'w': 1, 'l': 2, 't': 5, 'd': 3, 'o': 4, 'f': 2, 'v': 1, 'c': 2}

# %%
#11.Remove Duplicates:
nums=list(map(int,input("Enter comma seperated list: ").split(","))) #taking input
unique=[] #making a list that stores only unique elements
for i in nums:
    if i not in unique:
        unique.append(i)
#since we need to remove duplicate elements from the list we need to modify original list
nums=[]
for i in unique:
    nums.append(i)
print("List after removing duplicate elements:",nums)

#calculating mean and median of the unique numbers 
def mean_of_list(l):
    sum_of_terms=0
    for i in l:
        sum_of_terms+=i
    mean=(sum_of_terms)/len(l)
    return mean

def median_of_list(l):
    l.sort()
    if len(l)%2!=0:
        target=(len(l)+1)/2
        return l[target]
    else:
        value=(l[int(len(l)/2-1)]+l[int(len(l)/2)])/2 
        return value
print("mean:",mean_of_list(nums))
print("median:",median_of_list(nums))
# Out:
# Enter comma seperated list:  1,2,2,1,1,2,3,4,5,5,7
# List after removing duplicate elements: [1, 2, 3, 4, 5, 7]
# mean: 3.6666666666666665
# median: 3.5

# %%
#12.String Operations:
words=input("Enter space separated strings").split() #taking input
longest=''

#Finding the longest string
for i in words:
    if len(i)>len(longest):
        longest=i
print("the longest string:",longest)

#Counting how many strings start with a vowel
count=0
for i in words:
    if i[0] in 'aeiouAEIOU':
        count+=1
print("number of words starting with a vowel:",count)

#Analyzing distribution of string length using a histogram
import matplotlib.pyplot as plt
lengths=[]
for i in words:
    lengths.append(len(i))
plt.title("Word Length Data")
plt.xlabel("Word Length")
plt.ylabel("Frequency")
plt.hist(lengths)
plt.show()
# Out:
# Enter space separated strings Hi guys I am really enjoying doing this prerequisite test and learning new tools
# the longest string: prerequisite
# number of words starting with a vowel: 4

# %%
#13.Sorting Dictionaries:
def sort_by_key(data, key):
        return sorted(data, key=lambda x: x[key])
data = [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 22}]
sorted_data = sort_by_key(data, 'age')
print(sorted_data)
# Out:
# [{'name': 'Bob', 'age': 22}, {'name': 'Alice', 'age': 25}]

# %%
#14.Word Filtering and Sorting:
s=input()

#splitting string into list of words
words=s.split()

#removing all words that are shorter than 4 characters
words = [word for word in words if len(word) >= 4]

#sorting words alphabetically 
words.sort()

#visualizing word lengths using bar plot
import matplotlib.pyplot as plt
word_lengths=[]
for i in words:
    word_lengths.append(len(i))
plt.title("Word Lengths")
plt.xlabel("Words")
plt.ylabel("Length")
plt.bar(words,word_lengths)
plt.show()
# Out:
#  Hi this is just a demo sentence for data

# %%
#15.Anagram Finder:
word=input("Enter Word: ")
words=input("Enter space seperated words").split()

#function that checks if two words are anagrams
def anagram(x,y):
    x_list=[]
    y_list=[]
    for i in x:
        x_list.append(i)
    for i in y:
        y_list.append(i)
    x_list.sort()
    y_list.sort()
    for i in range(len(x_list)):
        if x_list[i]==y_list[i]:
            continue
        else:
            return False
    return True

#storing and displaying all anagrams
anagrams=[]
for term in words:
    if anagram(word,term):
        anagrams.append(term)
print("Anagrams of",word,"are:",anagrams)
# Out:
# Enter Word:  listen
# Enter space seperated words enlist google inlets banana
# Anagrams of listen are: ['enlist', 'inlets']

# %%
#16.Set Operations: (Learn this)

# %%
#17.File Operations: (Learn this)
nums=[10,21,36,49,33,11,15,20] #array data that will be written into the file

#writing the numbers into the file line by line
f=open("demo.txt","w+")
for i in nums:
    f.write(str(i) + "\n")
    
f.seek(0) #setting cursor back to the start of the file

#summing the numbers in the file by reading it line by line
summation=0
for i in f.readlines():
    summation+=int(i.strip())
print("Sum of numbers in the file:",summation)
f.close()
# Out:
# Sum of numbers in the file: 195

# %%
#18.Word Count and Frequency:
with open("sample.txt","r", encoding="utf8") as file: #file reading done default in binary, so it is encoded to read as a string
    text=file.read()
print(len(text.split()))
# Out:
# 512

# %%
#19.Random Number Generation:

#generating 100 random numbers and storing them in a file
import random
f=open("data.txt","w+")
for i in range(50):
    number= random.randint(1,100)
    f.write(str(number) + "\n")
f.seek(0) #setting cursor position back to start of file

#computing mean of the numbers in the file
summation=0
for i in f.readlines():
    summation+=int(i.strip())
mean=summation/50
print("Mean of numbers in the file:",mean)

#Visualizing distribution using a histogram
import matplotlib.pyplot as plt
f.seek(0)
data=[]
for i in f.readlines():
    data.append(int(i.strip()))
plt.title("Random Number Generation")
plt.xlabel("Number")
plt.ylabel("Frequency")
plt.hist(data)
f.close()
plt.show()
# Out:
# Mean of numbers in the file: 50.52

# %%
#20.

# %%
#21.Basic Statistics:

# %%
#22.Normalization:
nums=list(map(int,input("Enter array of numbers to be normalized").split()))

#writing function that performs normalization within 0 and 1
def normalizer(array):
    normalized_values=[]
    array.sort()
    minimum=array[0]
    maximum=array[-1]
    for i in array:
        term= (((i-minimum)/(maximum-minimum))*(1)) + 0
        normalized_values.append(term)
    return normalized_values

#visualizing data using line plot
plt.title("Normalization")
plt.plot(nums,label="Original values")
plt.plot(normalizer(nums),label="Normalized values")
plt.legend()
plt.show
# Out:
# Enter array of numbers to be normalized 10 8 8 9 7 6 3 5 5 7 9 10 10 8 8 6 6
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#23.Even or Odd:
num=int(input("Enter number to be checked:"))

#Logic to check whether number is even or odd, displaying the result
if num%2==0:
    print(num,"is even")
else:
    print(num,"is odd")
# Out:
# Enter number to be checked: 22
# 22 is even

# %%
#24.Grade Calculator:
mark=int(input("Enter score between 0 and 100:"))

#Creating a function that assignes grades based on mark 
def grade_finder(x):
    if x<=100 and x>90:
        return "A"
    elif x<=90 and x>80:
        return "B"
    elif x<=80 and x>70:
        return "C"
    elif x<=70 and x>60:
        return "D"
    else:
        return "F"

#Displaying the grade assigned
print("Grade assigned:",grade_finder(mark))
# Out:
# Enter score between 0 and 100: 90
# Grade assigned: B

# %%
#25.Leap Year Checker:
year=int(input("Enter year to be checked:"))

#Creating  a function to check if a year is a leap year with necessary constraints 
def leap_year_check(x):
    if x%4==0 and x%100!=0:
        return True
    elif x%100==0 and x%400==0:
        return True
    return False

#Displaying output
if leap_year_check(year):
    print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# Enter year to be checked: 2024
# 2024 is a leap year
